# %%
using PyPlot

n = 50
srand(1)
x = rand(n)
y = rand(n)
area = pi .* (15 .* rand(n)).^2 # 0 to 15 point radiuses
scatter(x, y, s=area, alpha=0.5)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10ceadb90>)
# PyObject <matplotlib.collections.PathCollection object at 0x115870e10>

# %%
help(repmat)
# Out:
# Base.repmat(A, n, m)
#
#    Construct a matrix by repeating the given matrix "n" times in
#    dimension 1 and "m" times in dimension 2.

# %%
using PyPlot
using Distributions
using QuantEcon: meshgrid

n = 50
x = linspace(-3, 3, n)
y = x

z = Array(Float64, n, n)
f(x, y) = cos(x^2 + y^2) / (1 + x^2 + y^2)
for i in 1:n
    for j in 1:n
        z[i, j] = f(x[i], y[j])
    end
end

fig = figure(figsize=(8,6))
ax = fig[:gca](projection="3d")
ax[:set_zlim](-0.5, 1.0)
xgrid, ygrid = meshgrid(x, y)
ax[:plot_surface](xgrid, ygrid, z, rstride=2, cstride=2, cmap=ColorMap("jet"), alpha=0.7, linewidth=0.25)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10cd91a90>)
# PyObject <mpl_toolkits.mplot3d.art3d.Poly3DCollection object at 0x1164fed90>

# %%
import PyPlot:plot

ts_length = 1000
epsilon_values = randn(ts_length)
plot(epsilon_values, "b-")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x116328690>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x115b9dad0>

# %%
typeof(epsilon_values)
# Out:
# Array{Float64,1}

# %%
x = ["Name: Naveen", age=31,epsilon_values]
# Out:
# 1002-element Array{Any,1}:
#    "Name: Naveen"
#  31
#   1.04249
#   0.0688753
#   1.52578
#   1.27436
#  -0.175285
#   0.0432078
#  -1.58355
#   1.41893
#   0.148581
#  -1.72545
#  -0.344878
#   ⋮
#  -1.43236
#  -0.822778
#   0.0631386
#  -1.06303
#   0.461882
#  -0.608089
#  -1.0352
#   1.1307
#  -0.0171069
#  -0.0505395
#   1.12623
#   0.159335

# %%
x
# Out:
# 2-element Array{Any,1}:
#    "Name: Naveen"
#  31

# %%
length(x)
# Out:
# 1002

# %%
pop(x)
# Out:
# pop not defined
# while loading In[20], in expression starting on line 1

# %%
pop!(x)
# Out:
# 0.15933524624889106

# %%
length(x)
# Out:
# 1001

# %%
using PyPlot
ts_length = 100
epsilon_values = Array(Float64, 100)
for i in 1:ts_length
    epsilon_values[i] = randn()
end
plot(epsilon_values, "b-")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10c33a510>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x116c1d6d0>

# %%
name = "Naveen"
age = 31

println("Name is $name. Age is $age")
# Out:
# Name is Naveen. Age is 31

# %%
using PyPlot

ts = 1000

eps_val = Array(Float64,ts)

i = 1000
while i >0
    eps_val[i] = randn()
    i = i - 1
end

plot(eps_val,"b-")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x116d9a2d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x11763fd90>

# %%
using PyPlot

function generateRand(n)
    ep_val = Array(Float64,n)
    for i in 1:n
        ep_val[i] = randn()
    end
    return ep_val
end

plot(generateRand(10000),"b-")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x116d8c950>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x113bb7b90>

# %%
using PyPlot
using Distributions

function plot_histogram(distribution, n)
    epsilon_values = rand(distribution, n)  # n draws from distribution
    PyPlot.plt.hist(epsilon_values)
end

lp = Laplace()
plot_histogram(lp, 500)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x117610ed0>)
# ([4.0,16.0,48.0,149.0,203.0,67.0,10.0,2.0,0.0,1.0],[-5.6876,-4.3072,-2.9268,-1.5464,-0.166001,1.2144,2.5948,3.97519,5.35559,6.73599,8.11639],{PyObject <matplotlib.patches.Rectangle object at 0x113c0a2d0>,PyObject <matplotlib.patches.Rectangle object at 0x113c0a910>,PyObject <matplotlib.patches.Rectangle object at 0x113c0af90>,PyObject <matplotlib.patches.Rectangle object at 0x113c10650>,PyObject <matplotlib.patches.Rectangle object at 0x113c10cd0>,PyObject <matplotlib.patches.Rectangle object at 0x113c17390>,PyObject <matplotlib.patches.Rectangle object at 0x113c17a10>,PyObject <matplotlib.patches.Rectangle object at 0x113c17f10>,PyObject <matplotlib.patches.Rectangle object at 0x113c1e750>,PyObject <matplotlib.patches.Rectangle object at 0x113c1edd0>})

# %%
function factorial2(n)
    x = 1
    for i in 1:n
        x = x * i
    end
    return x
end

println(factorial2(5))
# Out:
# 120

# %%
using Distributions

function binomial_rv(n, p)
    count = 0
    for i in 1:n
        u = rand(Uniform(0,1),n)
        println(u)
        for i in 1:length(u)
            if(u[i] < p)
                count = count + 1
            end
            i = i + 1
        end
    end
    
    return count
end

binomial_rv(10, 0.5)
# Out:
# [0.
# 5494991375896523,0.4663831282630313,0.39359945290133425,0.665755246846305,0.7093523257348202,0.3888226512738766,0.6610669921572132,0.7746957191897956,0.5783651668877003,0.9607200053404983]
# `isless` has no method matching isless(::Array{Float64,1}, ::Float64)
# while loading In[56], in expression starting on line 16
#
#  in binomial_rv at In[56]:8
