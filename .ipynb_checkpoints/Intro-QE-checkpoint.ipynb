# %%
println("Hello World!")

x = 1
y = 2
z = x + y

println("x + y = $z")
# Out:
# Hello World!
# x + y = 3

# %%
help(srand)
help(randn)

help(.*)
# Out:
# Base.srand([rng], seed)
#
#    Seed the RNG with a "seed", which may be an unsigned integer or a
#    vector of unsigned integers. "seed" can even be a filename, in
#    which case the seed is read from a file. If the argument "rng" is
#    not provided, the default global RNG is seeded.
# Base.randn([rng], dims or [dims...])
#
#    Generate a normally-distributed random number with mean 0 and
#    standard deviation 1. Optionally generate an array of normally-
#    distributed random numbers.
#  not defined
# while loading In[4], in expression starting on line 4
#
#  in eval at no file
#  in help at help.jl:102
#  in help at help.jl:168
#  in help at help.jl:183

# %%
using PyPlot

n = 50

srand(12345)

x = randn(n)
y = randn(n)

area = pi .* (15 .* randn(n)).^2

scatter(x,y,s=area, alpha=.3)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10eadafd0>)
# PyObject <matplotlib.collections.PathCollection object at 0x10eeb1690>

# %%
;ls
# Out:
# ls not defined
# while loading In[14], in expression starting on line 1

# %%
include("helloWorld.jl")
# Out:
# Hello World!
# i = 1
# i = 2
# i = 3

# %% [markdown]
# ;ls
